# %% [markdown]
# # Verificando a Versão do Python

# %%
#verificando a verção do Python
# !python --version
import pandas_profiling
# Out:
# Python 3.7.4

# %% [markdown]
# # Importando as biblotecas

# %%
# Importando as biblotecas
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
#plt.style.use('fivethirtyeight')


# %matplotlib inline

# %% [markdown]
# ##  Importando os três arquivos CSV utilizando a função read_csv do tipo (parsing) para conversão dos arquivos em Dataframes
# ### Todos os arquivos CSV foram abertos no VS Code e salvos com encoding UTF-8

# %%
''' Importando os três arquivos CSV utilizando a função read_csv do tipo
(parsing) para conversão dos arquivos em Dataframes '''

df2017 = pd.read_csv('donwloads/datatran2017.csv', sep =';')
df2018 = pd.read_csv('donwloads/datatran2018.csv', sep =';')
df2019 = pd.read_csv('donwloads/datatran2019.csv', sep =';')
df2020 = pd.read_csv('donwloads/datatran2020.csv', sep =';')

# %% [markdown]
# # Concatenando todos os arquivos em um só

# %%
#Usando a Função para Concatenar os DF
DadosAcidentes = pd.concat([df2017, df2018, df2019, df2020], sort=False, ignore_index=True)

# %% [markdown]
# ## Verificando a quantidade de linhas e colunas # de cada Dataset e realizando a soma de todos juntos.

# %%
print('Todas as Linhas X Colunas de 2017', df2017.shape)
print('Todos as Linhas X Colunas de 2018', df2018.shape)
print('Todos as Linhas X Colunas de 2019', df2019.shape)
print('Todos as Linhas X Colunas de 2020', df2020.shape)


print('SOMA DE TODOS OS DF Linhas X Colunas 2017+2018+2019+2020 = ', DadosAcidentes.shape)
# Out:
# Todas as Linhas X Colunas de 2017 (89563, 30)
# Todos as Linhas X Colunas de 2018 (69295, 30)
# Todos as Linhas X Colunas de 2019 (67446, 30)
# Todos as Linhas X Colunas de 2020 (39709, 30)
# SOMA DE TODOS OS DF Linhas X Colunas 2017+2018+2019+2020 =  (266013, 30)

# %%
DadosAcidentes.tail(10)
# Out:
#               id data_inversa     dia_semana   horario  uf     br     km  \
# 266003  308643.0   2020-02-13   quinta-feira  18:00:00  MG   40.0  247,2
# 266004  308645.0   2020-08-20   quinta-feira  20:40:00  PR  277.0    247
# 266005  308651.0   2020-06-25   quinta-feira  13:30:00  PA  222.0    100
# 266006  308653.0   2020-02-15         sábado  12:20:00  MG   50.0  109,1
# 266007  308667.0   2020-08-22         sábado  15:00:00  ES  262.0    100
# 266008  308807.0   2020-08-31  segunda-feira  05:40:00  RS  386.0    441
# 266009  308818.0   2020-04-25         sábado  11:28:00  PI  316.0  313,7
# 266010  308874.0   2020-08-26   quarta-feira  12:49:00  SC  101.0    131
# 266011  308901.0   2020-08-12   quarta-feira  20:20:00  BA  101.0     64
# 266012  309103.0   2020-08-20   quinta-feira  01:00:00  RJ  116.0    143
#
#                       municipio               causa_acidente  \
# 266003    SAO GONCALO DO ABAETE      Velocidade Incompatível
# 266004                    IRATI  Falta de Atenção à Condução
# 266005           RONDON DO PARA  Defeito Mecânico no Veículo
# 266006                  UBERABA  Falta de Atenção à Condução
# 266007  VENDA NOVA DO IMIGRANTE  Falta de Atenção à Condução
# 266008                   CANOAS             Animais na Pista
# 266009                    PICOS           Pista Escorregadia
# 266010       BALNEARIO CAMBORIU  Falta de Atenção à Condução
# 266011               ENTRE RIOS      Velocidade Incompatível
# 266012          DUQUE DE CAXIAS      Velocidade Incompatível
#
#                       tipo_acidente  ... feridos_graves ilesos ignorados  \
# 266003    Saída de leito carroçável  ...              1      0         0
# 266004              Colisão frontal  ...              0      2         0
# 266005    Saída de leito carroçável  ...              1      0         0
# 266006    Saída de leito carroçável  ...              0      1         0
# 266007  Colisão com objeto estático  ...              0      1         0
# 266008      Atropelamento de Animal  ...              0      2         0
# 266009                   Tombamento  ...              1      0         0
# 266010             Colisão traseira  ...              1      0         1
# 266011                   Tombamento  ...              0      1         0
# 266012  Colisão com objeto estático  ...              1      0         1
#
#        feridos veiculos      latitude     longitude  regional  delegacia  \
# 266003       1        1  -18,10887028   -45,4657742     SR-MG      UOP02
# 266004       0        2    -25,453166    -50,651406     SR-PR      UOP03
# 266005       1        1     -4,750449    -48,037624     SR-PA      UOP02
# 266006       2        1  -19,21477497   -48,1473349     SR-MG      UOP01
# 266007       0        1  -20,34889991    -41,102073     SR-ES      UOP02
# 266008       1        3    -29,882591    -51,233097     SR-RS      UOP01
# 266009       2        1   -7,07959049  -41,44975182     SR-PI      UOP01
# 266010       1        2  -26,99491643  -48,65875304     SR-SC      UOP03
# 266011       0        1  -11,96618423  -38,14476501     SR-BA      UOP04
# 266012       1        1  -22,67130326  -43,27744246     SR-RJ      UOP01
#
#           uop
# 266003  DEL14
# 266004  DEL03
# 266005  DEL02
# 266006  DEL13
# 266007  DEL01
# 266008  DEL01
# 266009  DEL04
# 266010  DEL04
# 266011  DEL01
# 266012  DEL01
#
# [10 rows x 30 columns]

# %%
# A função sample retorna uma amostra selecionada de forma aleatória usando a forma transposta.
DadosAcidentes.sample(5).T
# Out:
#                                              126025  \
# id                                           145536
# data_inversa                             2018-07-09
# dia_semana                            segunda-feira
# horario                                    12:10:00
# uf                                               PA
# br                                              316
# km                                                8
# municipio                                ANANINDEUA
# causa_acidente          Falta de Atenção à Condução
# tipo_acidente                       Colisão lateral
# classificacao_acidente          Com Vítimas Feridas
# fase_dia                                  Pleno dia
# sentido_via                             Decrescente
# condicao_metereologica                    Céu Claro
# tipo_pista                                    Dupla
# tracado_via                                    Reta
# uso_solo                                        Não
# pessoas                                           2
# mortos                                            0
# feridos_leves                                     1
# feridos_graves                                    0
# ilesos                                            1
# ignorados                                         0
# feridos                                           1
# veiculos                                          2
# latitude                                  -1,366236
# longitude                                -48,367805
# regional                                      SR-PA
# delegacia                                   DEL19/1
# uop                                        UOP05/PA
#
#                                            3174                       226513  \
# id                                           3791                     260274
# data_inversa                           2017-01-14                 2020-01-02
# dia_semana                                 sábado               quinta-feira
# horario                                  17:00:00                   04:00:00
# uf                                             MT                         MG
# br                                             70                        381
# km                                            212                        443
# municipio                        GENERAL CARNEIRO                SANTA LUZIA
# causa_acidente             Ultrapassagem Indevida         Pista Escorregadia
# tipo_acidente           Saída de leito carroçável  Saída de leito carroçável
# classificacao_acidente        Com Vítimas Feridas        Com Vítimas Feridas
# fase_dia                                Pleno dia                Plena Noite
# sentido_via                           Decrescente                Decrescente
# condicao_metereologica                  Céu Claro                      Chuva
# tipo_pista                                Simples                    Simples
# tracado_via                                  Reta                      Curva
# uso_solo                                      Não                        Não
# pessoas                                         1                          2
# mortos                                          0                          0
# feridos_leves                                   1                          2
# feridos_graves                                  0                          0
# ilesos                                          0                          0
# ignorados                                       0                          0
# feridos                                         1                          2
# veiculos                                        1                          1
# latitude                             -15,74223856                 -19,822546
# longitude                            -53,79334331                 -43,817345
# regional                                    SR-MT                      SR-MG
# delegacia                                  DEL2/5                     DEL4/1
# uop                                      UOP01/MT                   UOP01/MG
#
#                                          31550                        206804
# id                                        36420                       238004
# data_inversa                         2017-05-12                   2019-09-25
# dia_semana                          sexta-feira                 quarta-feira
# horario                                05:30:00                     19:45:00
# uf                                           SP                           MG
# br                                          116                           40
# km                                        347,5                        196,5
# municipio                              MIRACATU                JOAO PINHEIRO
# causa_acidente          Velocidade Incompatível  Falta de Atenção à Condução
# tipo_acidente                        Tombamento    Saída de leito carroçável
# classificacao_acidente              Sem Vítimas           Com Vítimas Fatais
# fase_dia                            Plena Noite                  Plena Noite
# sentido_via                         Decrescente                    Crescente
# condicao_metereologica                Céu Claro                        Chuva
# tipo_pista                                Dupla                      Simples
# tracado_via                               Curva                        Curva
# uso_solo                                    Não                          Não
# pessoas                                       1                            1
# mortos                                        0                            1
# feridos_leves                                 0                            0
# feridos_graves                                0                            0
# ilesos                                        1                            0
# ignorados                                     0                            0
# feridos                                       0                            0
# veiculos                                      1                            1
# latitude                             -24,051103                    -17,99611
# longitude                            -47,200657                    -45,84316
# regional                                  SR-SP                        SR-MG
# delegacia                                DEL6/4                      DEL4/14
# uop                                    UOP02/SP                     UOP02/MG

# %% [markdown]
# # Visualização dos Tipos de cada Coluna

# %%
DadosAcidentes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266013 entries, 0 to 266012
# Data columns (total 30 columns):
# id                        266013 non-null float64
# data_inversa              266013 non-null object
# dia_semana                266013 non-null object
# horario                   266013 non-null object
# uf                        266013 non-null object
# br                        265560 non-null float64
# km                        265560 non-null object
# municipio                 266013 non-null object
# causa_acidente            266013 non-null object
# tipo_acidente             266013 non-null object
# classificacao_acidente    266013 non-null object
# fase_dia                  266013 non-null object
# sentido_via               266013 non-null object
# condicao_metereologica    266013 non-null object
# tipo_pista                266013 non-null object
# tracado_via               266013 non-null object
# uso_solo                  266013 non-null object
# pessoas                   266013 non-null int64
# mortos                    266013 non-null int64
# feridos_leves             266013 non-null int64
# feridos_graves            266013 non-null int64
# ilesos                    266013 non-null int64
# ignorados                 266013 non-null int64
# feridos                   266013 non-null int64
# veiculos                  266013 non-null int64
# latitude                  266013 non-null object
# longitude                 266013 non-null object
# regional                  266013 non-null object
# delegacia                 266013 non-null object
# uop                       254923 non-null object
# dtypes: float64(2), int64(8), object(20)
# memory usage: 60.9+ MB

# %% [markdown]
# # Criação de uma nova coluna com um contador com auto incremento

# %%
DadosAcidentes['contador'] = range(1, 1+len(DadosAcidentes))

# %% [markdown]
# # Removendo Colunas do Dataframe

# %%
DadosAcidentes.pop("delegacia")
DadosAcidentes.pop("uop")
DadosAcidentes.pop("regional")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'delegacia'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-1471e4fe6ab3> in <module>
# ----> 1 DadosAcidentes.pop("delegacia")
#       2 DadosAcidentes.pop("uop")
#       3 DadosAcidentes.pop("regional")
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in pop(self, item)
#     860         3  monkey        NaN
#     861         """
# --> 862         result = self[item]
#     863         del self[item]
#     864         try:
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'delegacia'

# %% [markdown]
# # Ajustando os Dados para os Formatos Corretos e Otimização dos Tipos de dados para economizar memoria

# %%
DadosAcidentes.id = DadosAcidentes.id.astype('int32')
DadosAcidentes.data_inversa = DadosAcidentes.data_inversa.astype('object')
DadosAcidentes.dia_semana  = DadosAcidentes.dia_semana.astype('category')
DadosAcidentes.horario  = DadosAcidentes.horario.astype('object')
DadosAcidentes.uf = DadosAcidentes.uf.astype('category')
DadosAcidentes.br = DadosAcidentes.br.astype('object')
DadosAcidentes.km = DadosAcidentes.km.astype('object')
DadosAcidentes.municipio = DadosAcidentes.municipio.astype('category')
DadosAcidentes.causa_acidente = DadosAcidentes.causa_acidente.astype('category')
DadosAcidentes.tipo_acidente = DadosAcidentes.tipo_acidente.astype('category')
DadosAcidentes.classificacao_acidente = DadosAcidentes.classificacao_acidente.astype('category')
DadosAcidentes.fase_dia = DadosAcidentes.fase_dia.astype('category')
DadosAcidentes.sentido_via = DadosAcidentes.sentido_via.astype('category')
DadosAcidentes.condicao_metereologica = DadosAcidentes.condicao_metereologica.astype('category')
DadosAcidentes.tipo_pista = DadosAcidentes.tipo_pista.astype('category')
DadosAcidentes.tracado_via = DadosAcidentes.tracado_via.astype('category')
DadosAcidentes.uso_solo = DadosAcidentes.uso_solo.astype('category')
DadosAcidentes.pessoas = DadosAcidentes.pessoas.astype('uint8')
DadosAcidentes.mortos = DadosAcidentes.mortos.astype('uint8')
DadosAcidentes.feridos_leves = DadosAcidentes.feridos_leves.astype('uint8')
DadosAcidentes.feridos_graves = DadosAcidentes.feridos_graves.astype('uint8')
DadosAcidentes.ilesos = DadosAcidentes.ilesos.astype('uint8')
DadosAcidentes.ignorados = DadosAcidentes.ignorados.astype('uint8')
DadosAcidentes.feridos = DadosAcidentes.feridos.astype('uint8')
DadosAcidentes.veiculos = DadosAcidentes.veiculos.astype('uint8')
DadosAcidentes.latitude = DadosAcidentes.latitude.astype('int32')
DadosAcidentes.longitude = DadosAcidentes.longitude.astype('int32')
DadosAcidentes.contador = DadosAcidentes.contador.astype('int32')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-2188fd00f1e3> in <module>
#      24 DadosAcidentes.feridos = DadosAcidentes.feridos.astype('uint8')
#      25 DadosAcidentes.veiculos = DadosAcidentes.veiculos.astype('uint8')
# ---> 26 DadosAcidentes.latitude = DadosAcidentes.latitude.astype('int32')
#      27 DadosAcidentes.longitude = DadosAcidentes.longitude.astype('int32')
#      28 DadosAcidentes.contador = DadosAcidentes.contador.astype('int32')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     436                     kwargs[k] = obj.reindex(b_items, axis=axis, copy=align_copy)
#     437
# --> 438             applied = getattr(b, f)(**kwargs)
#     439             result_blocks = _extend_blocks(applied, result_blocks)
#     440
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors, values, **kwargs)
#     557
#     558     def astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
# --> 559         return self._astype(dtype, copy=copy, errors=errors, values=values, **kwargs)
#     560
#     561     def _astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in _astype(self, dtype, copy, errors, values, **kwargs)
#     641                     # _astype_nansafe works fine with 1-d only
#     642                     vals1d = values.ravel()
# --> 643                     values = astype_nansafe(vals1d, dtype, copy=True, **kwargs)
#     644
#     645                 # TODO(extension)
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     705         # work around NumPy brokenness, #1987
#     706         if np.issubdtype(dtype.type, np.integer):
# --> 707             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     708
#     709         # if we have a datetime/timedelta array of objects
#
# pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: '-23,09880731'

# %%
DadosAcidentes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266013 entries, 0 to 266012
# Data columns (total 28 columns):
# id                        266013 non-null int32
# data_inversa              266013 non-null object
# dia_semana                266013 non-null category
# horario                   266013 non-null object
# uf                        266013 non-null category
# br                        265560 non-null object
# km                        265560 non-null object
# municipio                 266013 non-null category
# causa_acidente            266013 non-null category
# tipo_acidente             266013 non-null category
# classificacao_acidente    266013 non-null category
# fase_dia                  266013 non-null category
# sentido_via               266013 non-null category
# condicao_metereologica    266013 non-null category
# tipo_pista                266013 non-null category
# tracado_via               266013 non-null category
# uso_solo                  266013 non-null category
# pessoas                   266013 non-null uint8
# mortos                    266013 non-null uint8
# feridos_leves             266013 non-null uint8
# feridos_graves            266013 non-null uint8
# ilesos                    266013 non-null uint8
# ignorados                 266013 non-null uint8
# feridos                   266013 non-null uint8
# veiculos                  266013 non-null uint8
# latitude                  266013 non-null object
# longitude                 266013 non-null object
# contador                  266013 non-null int32
# dtypes: category(12), int32(2), object(6), uint8(8)
# memory usage: 19.6+ MB

# %%
DadosAcidentes.shape
# Out:
# (266013, 28)

# %% [markdown]
# # Agrupamento de UF por Região  e criação da Coluna Regiões

# %%
norte = ['AC', 'AP', 'AM', 'PA', 'RO', 'RR', 'TO']

nordeste = ['AL', 'BA', 'CE', 'MA', 'PB', 'PE', 'PI', 'RN', 'SE']

centro_oeste = ['GO', 'MT', 'MS', 'DF']

sudeste = ['ES', 'MG', 'RJ', 'SP']

sul = ['PR', 'SC', 'RS']

regioes = []

for x in DadosAcidentes.uf:
    if x in norte:
        regioes.append('NORTE')
    
    if x in nordeste:
        regioes.append('NORDESTE')
        
    if x in centro_oeste:
        regioes.append('CENTRO-OESTE')
        
    if x in sudeste:
        regioes.append('SUDESTE')
        
    if x in sul:
        regioes.append('SUL')
        
    if x == '***':
        regioes.append('***')
        
print(regioes[0:10])
print(len(regioes))
DadosAcidentes['regioes'] = regioes
DadosAcidentes.regioes = DadosAcidentes.regioes.astype('category')
# Out:
# ['SUL', 'SUL', 'SUL', 'CENTRO-OESTE', 'SUL', 'CENTRO-OESTE', 'NORDESTE', 'NORTE', 'SUL', 'SUL']
# 266013

# %%
DadosAcidentes.columns
# Out:
# Index(['id', 'data_inversa', 'dia_semana', 'horario', 'uf', 'br', 'km',
#        'municipio', 'causa_acidente', 'tipo_acidente',
#        'classificacao_acidente', 'fase_dia', 'sentido_via',
#        'condicao_metereologica', 'tipo_pista', 'tracado_via', 'uso_solo',
#        'pessoas', 'mortos', 'feridos_leves', 'feridos_graves', 'ilesos',
#        'ignorados', 'feridos', 'veiculos', 'latitude', 'longitude', 'contador',
#        'regioes'],
#       dtype='object')

# %%
DadosAcidentes.query('causa_acidente=="Ingestão de Álcool"')
# Out:
#             id data_inversa     dia_semana   horario  uf   br     km  \
# 4           13   2017-01-01        domingo  00:00:00  SC  280   77,3
# 6           15   2017-01-01        domingo  00:01:00  PB  104    3,4
# 7           16   2017-01-01        domingo  00:30:00  TO  153  141,7
# 15          24   2017-01-01        domingo  02:10:00  SC  101     45
# 17          26   2017-01-01        domingo  00:30:00  GO   20   21,5
# ...        ...          ...            ...       ...  ..  ...    ...
# 265925  306852   2020-08-31  segunda-feira  18:40:00  RN  304    284
# 265927  306883   2020-07-04         sábado  09:30:00  BA  242    850
# 265938  307131   2020-05-10        domingo  15:20:00  PB  230   21,2
# 265955  307526   2020-05-04  segunda-feira  18:00:00  PI  402   95,8
# 265972  308033   2020-07-26        domingo  18:20:00  RJ  116    187
#
#                 municipio      causa_acidente                 tipo_acidente  \
# 4                  CORUPA  Ingestão de Álcool     Saída de leito carroçável
# 6           NOVA FLORESTA  Ingestão de Álcool                    Tombamento
# 7               ARAGUAINA  Ingestão de Álcool              Colisão traseira
# 15              JOINVILLE  Ingestão de Álcool              Colisão traseira
# 17                FORMOSA  Ingestão de Álcool     Saída de leito carroçável
# ...                   ...                 ...                           ...
# 265925            MACAIBA  Ingestão de Álcool               Colisão frontal
# 265927          BARREIRAS  Ingestão de Álcool                    Tombamento
# 265938        JOAO PESSOA  Ingestão de Álcool                    Tombamento
# 265955  CAJUEIRO DA PRAIA  Ingestão de Álcool  Queda de ocupante de veículo
# 265972        NOVA IGUACU  Ingestão de Álcool              Colisão traseira
#
#         ... feridos_leves feridos_graves ilesos ignorados feridos veiculos  \
# 4       ...             1              0      0         0       1        1
# 6       ...             0              0      0         0       0        1
# 7       ...             2              0      1         1       2        2
# 15      ...             1              0      1         0       1        2
# 17      ...             0              0      1         0       0        1
# ...     ...           ...            ...    ...       ...     ...      ...
# 265925  ...             1              1      0         0       2        2
# 265927  ...             1              1      2         0       2        1
# 265938  ...             0              1      0         0       1        1
# 265955  ...             1              0      1         0       1        2
# 265972  ...             0              0      3         0       0        3
#
#             latitude     longitude  contador       regioes
# 4       -26,44675249  -49,20166969         5           SUL
# 6            -6,4622      -36,1899         7      NORDESTE
# 7        -7,18668515  -48,22970957         8         NORTE
# 15          -26,3487      -48,8574        16           SUL
# 17      -15,54699656  -47,16523376        18  CENTRO-OESTE
# ...              ...           ...       ...           ...
# 265925   -5,87912197  -35,45510001    265926      NORDESTE
# 265927  -12,10967583  -45,28842497    265928      NORDESTE
# 265938       -7,1415      -34,8519    265939      NORDESTE
# 265955   -3,06582162  -41,29346991    265956      NORDESTE
# 265972  -22,73883756  -43,47245197    265973       SUDESTE
#
# [20305 rows x 29 columns]

# %%
sorted(DadosAcidentes.sentido_via.unique())
# Out:
# ['Crescente', 'Decrescente', 'Não Informado']

# %% [markdown]
# # Visualização de Outliers

# %%
sns.boxplot(x=DadosAcidentes['mortos'])

# %%
DadosAcidentes.mortos.value_counts()
# Out:
# 0     248979
# 1      14997
# 2       1473
# 3        349
# 4        127
# 5         47
# 6         19
# 7          9
# 8          6
# 11         2
# 9          2
# 21         1
# 13         1
# 10         1
# Name: mortos, dtype: int64

# %%
DadosAcidentes.query('mortos == 21')
# Out:
#           id data_inversa    dia_semana   horario  uf   br     km  municipio  \
# 41869  48048   2017-06-22  quinta-feira  06:10:00  ES  101  343,4  GUARAPARI
#
#                 causa_acidente tipo_acidente  ... feridos_leves  \
# 41869  Velocidade Incompatível    Tombamento  ...            13
#
#       feridos_graves ilesos ignorados feridos veiculos     latitude  \
# 41869              9      0         0      22        4  -20,6636897
#
#          longitude  contador  regioes
# 41869  -40,5939666     41870  SUDESTE
#
# [1 rows x 29 columns]

# %% [markdown]
# # Verificação de Dados Faltantes

# %%
DadosAcidentes.isnull().sum()
# Out:
# id                          0
# data_inversa                0
# dia_semana                  0
# horario                     0
# uf                          0
# br                        453
# km                        453
# municipio                   0
# causa_acidente              0
# tipo_acidente               0
# classificacao_acidente      0
# fase_dia                    0
# sentido_via                 0
# condicao_metereologica      0
# tipo_pista                  0
# tracado_via                 0
# uso_solo                    0
# pessoas                     0
# mortos                      0
# feridos_leves               0
# feridos_graves              0
# ilesos                      0
# ignorados                   0
# feridos                     0
# veiculos                    0
# latitude                    0
# longitude                   0
# contador                    0
# regioes                     0
# dtype: int64

# %%
DadosAcidentes.update(DadosAcidentes['br'].fillna('Não Informado'))
DadosAcidentes.update(DadosAcidentes['km'].fillna('Não Informado'))

# %%
DadosAcidentes.isnull().sum()
# Out:
# id                        0
# data_inversa              0
# dia_semana                0
# horario                   0
# uf                        0
# br                        0
# km                        0
# municipio                 0
# causa_acidente            0
# tipo_acidente             0
# classificacao_acidente    0
# fase_dia                  0
# sentido_via               0
# condicao_metereologica    0
# tipo_pista                0
# tracado_via               0
# uso_solo                  0
# pessoas                   0
# mortos                    0
# feridos_leves             0
# feridos_graves            0
# ilesos                    0
# ignorados                 0
# feridos                   0
# veiculos                  0
# latitude                  0
# longitude                 0
# contador                  0
# regioes                   0
# dtype: int64

# %% [markdown]
# # Padronização dos dados para .TITLE()  - Deixa as letras de cada palavra da string maiúscula.

# %%
DadosAcidentes['dia_semana'] = DadosAcidentes['dia_semana'].str.title()
DadosAcidentes['causa_acidente'] = DadosAcidentes['causa_acidente'].str.title()
DadosAcidentes['tipo_acidente'] = DadosAcidentes['tipo_acidente'].str.title()
DadosAcidentes['classificacao_acidente'] = DadosAcidentes['classificacao_acidente'].str.title()
DadosAcidentes['fase_dia'] = DadosAcidentes['fase_dia'].str.title()
DadosAcidentes['sentido_via'] = DadosAcidentes['sentido_via'].str.title()
DadosAcidentes['condicao_metereologica'] = DadosAcidentes['condicao_metereologica'].str.title()
DadosAcidentes['tipo_pista'] = DadosAcidentes['tipo_pista'].str.title()
DadosAcidentes['tracado_via'] = DadosAcidentes['tracado_via'].str.title()
DadosAcidentes['uso_solo'] = DadosAcidentes['uso_solo'].str.title()
DadosAcidentes['uf'] = DadosAcidentes['uf'].str.upper()
DadosAcidentes['municipio'] = DadosAcidentes['municipio'].str.title()
DadosAcidentes['causa_acidente'] = DadosAcidentes['causa_acidente'].str.title()
DadosAcidentes['classificacao_acidente'] = DadosAcidentes['classificacao_acidente'].str.title()
DadosAcidentes['fase_dia'] = DadosAcidentes['fase_dia'].str.title()
DadosAcidentes['sentido_via'] = DadosAcidentes['sentido_via'].str.title()
DadosAcidentes['tipo_pista'] = DadosAcidentes['tipo_pista'].str.title()
DadosAcidentes['tracado_via'] = DadosAcidentes['tracado_via'].str.title()
DadosAcidentes['uso_solo'] = DadosAcidentes['uso_solo'].str.title()
DadosAcidentes['regioes'] = DadosAcidentes['regioes'].str.title()

DadosAcidentes.columns = DadosAcidentes.columns.str.title()

# %%
# Identificando dados faltantes novamente
DadosAcidentes.isnull().sum()
# Out:
# Id                        0
# Data_Inversa              0
# Dia_Semana                0
# Horario                   0
# Uf                        0
# Br                        0
# Km                        0
# Municipio                 0
# Causa_Acidente            0
# Tipo_Acidente             0
# Classificacao_Acidente    0
# Fase_Dia                  0
# Sentido_Via               0
# Condicao_Metereologica    0
# Tipo_Pista                0
# Tracado_Via               0
# Uso_Solo                  0
# Pessoas                   0
# Mortos                    0
# Feridos_Leves             0
# Feridos_Graves            0
# Ilesos                    0
# Ignorados                 0
# Feridos                   0
# Veiculos                  0
# Latitude                  0
# Longitude                 0
# Contador                  0
# Regioes                   0
# dtype: int64

# %%
 # %matplotlib inline

from wordcloud import WordCloud, STOPWORDS
plt.style.use('seaborn')
wrds1 = DadosAcidentes["causa_acidente"].str.split("(").str[0].value_counts().keys()




 lista de stopword
stopwords = set(STOPWORDS)
stopwords.update(["da", "meu", "em", "você", "de", "ao", "os", "ou", "pelo", "na", "sobre", "as"])

wc1 = WordCloud(stopwords=stopwords,scale=5,max_words=50,colormap="rainbow",background_color="black").generate(" ".join(wrds1))
plt.figure(figsize=(20,10))
plt.imshow(wc1,interpolation="bilinear")
plt.axis("off")
plt.title("Nuvem de Palavras das Causas de Acidentes",color='c', size='40')
plt.show()''''''

# %%
# Salvando todas as alterações desse dataset em um arquivo csv
DadosAcidentes.to_csv('tcc-2020-v4.csv', sep=';', encoding='utf-8-sig')
