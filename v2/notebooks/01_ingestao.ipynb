# %% [markdown]
# # 01 — Ingestão dos dados PRF (2021-2025)
#
# Notebook de validação da ingestão. Para uso produtivo, prefira `python -m src.data.ingest`.

# %%
import sys, pathlib
sys.path.append(str(pathlib.Path.cwd().parent))
from src.data.ingest import download_year, PRF_URLS
PRF_URLS

# %% [markdown]
# ## Baixar um ano específico para inspeção

# %%
# download_year(2024)

# %% [markdown]
# ## Inspecionar o CSV bruto

# %%
import pandas as pd
df = pd.read_csv('../data/raw/datatran2024.csv', sep=';', encoding='latin-1', decimal=',', nrows=5)
df
